# %%
print(5>>1)
print(2>>1)
print(10<<2)
# Out:
# 2
# 1
# 40

# %%
age=11
if(age==10):
    print("your age is 10")
elif(age==20):
    print("your age is 20")
else:
    print("your age is",age)
# Out:
# your age is 11

# %%
l=[1,2,3,4,5,6]
if 2 in l:
    print("list l contains 2")
else:
    print("list l not contain 2")
# Out:
# list l contains 2

# %%
x=10
y=10
if x is y:
    print("x is y")
else:
    print("x is not y")
# Out:
# x is y

# %%
age=int(input())
if(age>=18):
    print("eligible to vote")
else:
    print("not eligible to vote")
# Out:
# 1
# not eligible to vote

# %%
math=int(input())
phy=int(input())
che=int(input())
print("math marks:",math)
print("phy marks:",phy)
print("che marks:",che)
print("total marks:",math+phy+che)
print("total marks:",(math+phy+che)/3)

# %%
bal=1000
acc=input("enter your acc number:")
op=int(input("options from bank\n1.check balance\n 2.with draw amount \n 3.add amount\nplease select one option\n"))

if(op==1):
    print(bal)
elif(op==2):
    amo=int(input("enter amount what you want to with draw :"))
    bal=bal-amo
    print("your amount :",amo)
    print("remaing balace is ",bal)
    
elif(op==3):
    amo=int(input("enter amount what you want to add"))
    bal=bal+amo
    print(bal)
else:
    print("enter a vaild option")
# Out:
# enter your acc number:123
# options from bank
# 1.check balance
#  2.with draw amount
#  3.add amount
# please select one option
# 2
# enter amount what you want to with draw300
# 700

# %%
items=int(input("enter number of items : "))
l=[]
for i in range(0,items):
    l.append(int(input("cost of item:")))
print("------------billing-----------")
for i in range(0,items):
    print("item ",i+1,l[0])
print("total amount",sum(l))

# %%
num=int(input())
print("even" if num%2==0 else "odd")
# Out:
# 2
# even

# %%
a=int(input())
b=int(input())
print("bf swaping")
print("a",a)
print("b",b)
print("af swaping")
a=b+a
b=a-b
a=a-b
print("a",a)
print("b",b)
# Out:
# 2
# 7
# bf swaping
# a 2
# b 7
# af swaping
# a 7
# b 2

# %%
import sys
a=3+5j
b=10+15j
print(a+b)
print(sys.getsizeof(a))
print(sys.getsizeof(b))
print(sys.getsizeof(a+b))
# Out:
# (13+20j)
# 32
# 32
# 32

# %%
tikets=[20,30,10]
price=[100,90,150]
mov=int(input("movies avalble\n1.mass -per 100\n2.one -per 90\n3.ride -per 150\n"))
tik=int(input("enter numbeer of tickets required \n"))
if(tik<=tikets[mov-1]):
    print("your tickets",tik)
    tikets[mov-1]-tik
    print("your bill ",tik*price[mov-1])
else:
    print("insufficent tickets\n")
    print("number of tickets avalibe",tikets[mov-1])
# Out:
# movies avalble
# 1.mass -per 100
# 2.one -per 90
# 3.ride -per 150
# 2
# enter numbeer of tickets required
# 40
# insufficent tickets
#
# number of tickets avalibe 30
