# %% [markdown]
# #check username and pasword is correct or not

# %%
name="admin"
pwd=1234
user=input("enter user name")
pas=int(input("enter pass"))
if user==name and pwd==pas:
    print("login succ")
# Out:
# enter user name
# enter pass
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 4
#       2 pwd=1234
#       3 user=input("enter user name")
# ----> 4 pas=int(input("enter pass"))
#       5 if user==name and pwd==pas:
#       6     print("login succ")
#
# ValueError: invalid literal for int() with base 10: ''

# %%
a,b,c=map(int,input("enter 3 num").split(","))
if(a>b):
    if(a>c):
        print(a)
    else:
        print(c)
elif(b>a):
    if(b>c):
        print(b)
    else:
        print(c)
else:
    print(c)
# Out:
# enter 3 num2,3,1
# 3

# %%
x=int(input("enter a number"))
print("h") if x>80 else print("m") if x>50 and x<
# Out:
#   Cell In[1], line 2
#     print("h") if x>80 else print("m") if x>50 and x<
#                             ^
# SyntaxError: expected 'else' after 'if' expression

# %%
a=int(input("enter a "))
b=int(input("enter b "))
op=input("nter a operater")
match op:
    case "+" :
        print(f"+ {a+b}")
    case "-":
        print(f"- {a-b}")
    case "*":
        print(f"* {a*b}")
    case "/":
        print(f"/ {a/b}")
# Out:
# enter a 4
# enter b 5
# nter a operater*
# * 20

# %%
x=True
x and print("with out if ")
# Out:
# with out if

# %%
print("-----------------doms-------------")
print("""
Menu Items 
Veg Items: Tokens 101-106
Non-Veg Items: Tokens 201-206
Combo Items: Tokens 301-302

veg:
burg------------------------------->70 (101)
panner burg------------------------>80 (102)
panner pizz------------------------>120 (103)
mix pizz--------------------------->110 (104)
onin pizz-------------------------->100 (105)
chezz bustpizz--------------------->120 (106)

Non veg:
chik burg--------------------------->100 (201)
doublchik burg---------------------->150 (202)
chiken pizz------------------------>150 (203)
kabab pizz--------------------------->160 (204)
mix pizz--------------------------->180 (205)
chezz bustpizz--------------------->200 (206)


comboo:
veg+chik bug----------------------->150 (301)
doublchik+doub veg burg------------>200 (302)
""")
token_number=int(input("enter token number"))
match token_number:
        case 101:
            order_item = "Burg (Veg)"
            bill_amount = 70
        case 102:
            order_item = "Panner Burg (Veg)"
            bill_amount = 80
        case 103:
            order_item = "Panner Pizz (Veg)"
            bill_amount = 120
        case 104:
            order_item = "Mix Pizz (Veg)"
            bill_amount = 110
        case 105:
            order_item = "Onion Pizz (Veg)"
            bill_amount = 100
        case 106:
            order_item = "Chezz Bust Pizz (Veg)"
            bill_amount = 120
        case 201:
            order_item = "Chik Burg (Non-Veg)"
            bill_amount = 100
        case 202:
            order_item = "Doublchik Burg (Non-Veg)"
            bill_amount = 150
        case 203:
            order_item = "Chiken Pizz (Non-Veg)"
            bill_amount = 150
        case 204:
            order_item = "Kabab Pizz (Non-Veg)"
            bill_amount = 160
        case 205:
            order_item = "Mix Pizz (Non-Veg)"
            bill_amount = 180
        case 206:
            order_item = "Chezz Bust Pizz (Non-Veg)"
            bill_amount = 200
        case 301:
            order_item = "Veg + Chik Burg (Combo)"
            bill_amount = 150
        case 302:
            order_item = "Doublchik + Doub Veg Burg (Combo)"
            bill_amount = 200

if order_item != "Not Found":
        print(f"Order Details for Token {token_number}:")
        print(f"Items Ordered: {order_item}")
        print(f"Total Bill Amount: Rs.{bill_amount}")
# Out:
# -----------------doms-------------
#
# Menu Items
# Veg Items: Tokens 101-106
# Non-Veg Items: Tokens 201-206
# Combo Items: Tokens 301-302
#
# veg:
# burg------------------------------->70 (101)
# panner burg------------------------>80 (102)
# panner pizz------------------------>120 (103)
# mix pizz--------------------------->110 (104)
# onin pizz-------------------------->100 (105)
# chezz bustpizz--------------------->120 (106)
#
# Non veg:
# chik burg--------------------------->100 (201)
# doublchik burg---------------------->150 (202)
# chiken pizz------------------------>150 (203)
# kabab pizz--------------------------->160 (204)
# mix pizz--------------------------->180 (205)
# chezz bustpizz--------------------->200 (206)
#
#
# comboo:
# veg+chik bug----------------------->150 (301)
# doublchik+doub veg burg------------>200 (302)
#
# enter token number101
# Order Details for Token 101:
# Items Ordered: Burg (Veg)
# Total Bill Amount: Rs.70
